# %% [markdown]
# # Moaaz Trend Pipeline
# Run training and prediction for the Moaaz Trend forecasting model.

# %%
# Imports and Setup
import sys
import os
from pathlib import Path
import pandas as pd

# Ensure we are operating relative to the /functions directory
FUNCTIONS_DIR = Path.cwd().parent
sys.path.insert(0, str(FUNCTIONS_DIR))

# Firebase setup
from firebase_admin import initialize_app, credentials, get_app
from google.cloud import firestore as google_firestore
import logging

logging.basicConfig(level=logging.INFO)

# Use direct path to service account key inside /functions
service_account_path = FUNCTIONS_DIR / 'serviceAccountKey.json'

# Initialize Firebase Admin SDK
try:
    app = get_app()
except ValueError:
    cred = credentials.Certificate(service_account_path)
    app = initialize_app(cred, {'storageBucket': 'uno-y-b48fb.appspot.com'})

# Create Firestore client using the same credentials
firestore_client = google_firestore.Client.from_service_account_json(str(service_account_path))

# planogram imports
from planogram import data_loader
# Load data
print("Loading data...")
firebase_data = data_loader.load_firebase_collections(firestore_client)  # Loads all collections
sales_data = data_loader.load_all_sales_data(firestore_client) # Loads and combines historical + latest sales
sales_data = data_loader.enrich_with_purchase_prices(sales_data, firebase_data.get('product_purchase_prices'))
print("Data loaded.")

products_df = firebase_data.get('products')
machines_df = firebase_data.get('machines')
# Out:
# WARNING:root:Font file not found at fonts/Inter.ttf
# WARNING:root:Font file not found at fonts/Inter-Bold.ttf
# WARNING:root:Font file not found at fonts/Inter-Italic.ttf
# Loading data...
# Loading collection: app_machines
# app_machines slots cleaned: 8193 -> 8172 (removed 21, 0.26%)
# app_machines: 234 rows (machines themselves not filtered)
# Loading collection: products
# products (filtered unspecific rows): 2410 -> 1961 rows (removed 449, 18.63%)
# Loading collection: product_purchase_prices
# product_purchase_prices: 1370 -> 1370 rows (removed 0, 0.00%)
# Loading historical sales from Parquet files...
# Historical sales (after filtering): 6979402 -> 5390446 rows (removed 1588956, 22.77%)
# No latest sales provided; only historical sales will be used.
# Data loaded.

# %%
# Import Moaaz Trend functions
from planogram.moaaz_trend import moaaz_train, moaaz_predict, map_ean_to_product_name

print(f"Machines: {len(machines_df)}")
print(f"Products: {len(products_df)}")
print(f"Sales: {len(sales_data)}")

artifact_dir = FUNCTIONS_DIR / 'planogram' / 'moaaz_trend' / 'artifact'
if not artifact_dir.exists():
    raise FileNotFoundError(f"Artifact directory does not exist: {artifact_dir}")
model_path = artifact_dir  # 'model_path' now refers to the artifact directory
# Out:
# Machines: 234
# Products: 1961
# Sales: 5390446

# %%
# Train Model
print("Starting Training...")

forecaster = moaaz_train(
    sales_df=sales_data,
    products_df=products_df,
    machines_df=machines_df,
    model_path=model_path
)
print(f"Training Complete. Model saved to {model_path}")
# Out:
# INFO:planogram.moaaz_trend.train_predict:Starting moaaz_train pipeline...
# Starting Training...
# INFO:planogram.moaaz_trend.train_predict:Processing sales data...
# 🚀 STARTING ETL PIPELINE
# ======================================================================
# Input: 5,390,446 raw transactions
# Input columns: 32 - address, card_brand, card_type, category, currency, customer_id, ean, is_ICA_refiller, latitude, local_timestamp, longitude, machine_eva_group, machine_group_tag, machine_id, machine_key, machine_model, machine_name, machine_sub_group, moms, nayax_name, position, price, product_name, provider, purchase_price_kr, pusher_friendly, refiller, sielaff_id, spiral, subcategory, too_unspecific, width
# Date range: 2018-06-29 14:18:33+00:00 to 2025-11-18 23:59:50+00:00
# Machines: 1,930
# Products: 1,358
# ======================================================================
#
# 🔧 STEP 1: DATA CLEANING
# 🧹 CLEANING SALES DATA
# ==================================================
# Starting with 5,390,446 transactions
# ✓ Removed 250,969 rows with missing essential fields
# ✓ Removed 627 test transactions (price ≤ 2 SEK)
# ✓ Removed 444 transactions from 127 test machines
# ✓ Removed 39,488 rows with missing provider
# ✓ Kept 14 relevant columns
# ==================================================
# ✅ CLEANING COMPLETE
#    Original: 5,390,446 transactions
#    Removed:  291,528 transactions (5.4%)
#    Final:    5,098,918 transactions
# ==================================================
# ✓ After cleaning: 5,098,918 transactions
# ✓ Columns: 14 - category, customer_id, ean, local_timestamp, machine_eva_group, machine_key, machine_sub_group, position, price, product_name, provider, purchase_price_kr, refiller, subcategory
# ✓ Total sales (transactions): 5,098,918
#
# 📊 STEP 2a: POSITION-LEVEL WEEKLY AGGREGATION
# 📊 AGGREGATING TO WEEKLY LEVEL (POSITION-LEVEL)
# ==================================================
# Starting with 5,098,918 transactions
# ✓ Grouping by: machine_key, position, ean, year, week
# ==================================================
# ✅ WEEKLY AGGREGATION COMPLETE
#    Original transactions: 5,098,918
#    Weekly records:        1,563,950
#    Compression ratio:     3.3x
#    Unique machines:       1,606
#    Unique products:       1,253
#    Unique positions:      150
# ==================================================
# ✓ After aggregation: 1,563,950 records
# ✓ Columns: 19 - category_first, customer_id_first, ean, first_sale_timestamp, machine_eva_group_first, machine_key, machine_sub_group_first, position, price_mean, product_name_first, provider_first, purchase_price_kr_first, refiller_first, subcategory_first, week, week_end_first, week_start_first, weekly_sales, year
# ✓ Total sales: 5,098,918 (expected: 5,098,918, diff: 0)
#
# 🏗️ STEP 2b: BUILDING MACHINE SNAPSHOTS
# 🏗️ BUILDING MACHINE SNAPSHOTS
# ==================================================
# 🔄 DETECTING PRODUCT SWAPS
# ==================================================
# ✓ Detected 43,549 product swaps
# ==================================================
# 📏 CALCULATING WEEK SHARES
# ==================================================
# ✓ Calculated week shares for 43,549 swapped products
# ✓ 1,520,401 products with full week (week_share = 1.0)
# ==================================================
# ➕ ADDING OUTGOING PRODUCT ENTRIES
# ==================================================
# ✓ Building metadata lookup for 43,549 outgoing products...
# Processing swaps:   0%|          | 0/15501 [00:00<?, ?positions/s]
# ✓ Added 30,747 outgoing product entries
# ==================================================
# 📸 CREATING COMPLETE SNAPSHOTS (OPTIMIZED)
# ==================================================
# ✓ Generating week_start and week_end from year/week
# ✓ Input: 1,594,697 records
# ✓ Built grid: 15,997,910 potential slots
# ✓ Merged with data: 16,037,750 records
# ✓ Forward-filled 4 columns
# ✓ Removed empty slots: 6,158,263 records remain
# ✓ Removed 3,353,476 stale records (≥8 weeks no sales)
# ⚠️  Fixed 612 positions with >2 entries in same week
# ✓ Removed 628 duplicate entries
# ✓ Final snapshots: 2,804,159 records
# ✓ Expansion ratio: 1.76x
# ==================================================
# 🧹 REMOVING STALE PRODUCTS AND MACHINES
# ==================================================
# Step 1: Identifying stale products (8+ weeks zero sales)...
# ✓ Removed 477,976 stale entries from 40,738 products
# Step 2: Identifying decommissioned machines (3+ weeks total zero sales)...
# ✓ Removed 0 entries from 281 machines with decommissioned periods
# ==================================================
# ✅ REMOVAL COMPLETE
#    Original records: 2,804,159
#    Removed:          477,976 (17.0%)
#    Final records:    2,326,183
# ==================================================
# WARNING:planogram.moaaz_trend.utils.calendar:Holidays file not found: /Users/sam/Documents/Code/Planogram/uno/functions/data/raw/SwedishHolidays(2017-26).csv
# ==================================================
# ✅ MACHINE SNAPSHOTS COMPLETE
# ==================================================
# ✓ After snapshot creation: 2,326,183 records
# ✓ Columns: 27 - _is_zero, _streak_group, category_first, customer_id_first, date_key, ean, first_sale_timestamp, machine_eva_group_first, machine_key, machine_sub_group_first, position, prev_ean, price_mean, product_name_first, provider_first, purchase_price_kr_first, refiller_first, subcategory_first, was_replaced, week, week_end, week_end_first, week_share, week_start, week_start_first, weekly_sales, year
# ✓ Total sales: 5,098,747 (expected: 5,098,918, diff: 171)
#
# 📅 STEP 3: CALENDAR INTEGRATION
# 📅 ADDING CALENDAR INFORMATION
# ==================================================
# Processing 2,326,183 weekly records
# ✓ Initializing Swedish holiday calendar
# ✓ Found 383 unique weeks
# ✓ Pre-calculating working days and holidays...
# Calculating calendar:   0%|          | 0/383 [00:00<?, ?weeks/s]
# ✓ Pre-calculated calendar info for 383 unique weeks
# ✓ Mapping calendar info (vectorized)...
# ==================================================
# ✅ CALENDAR INTEGRATION COMPLETE
#    Records processed: 2,326,183
#    Unique weeks:      383
# ==================================================
# ✓ After calendar: 29 columns (added 2)
#
# ======================================================================
# 🎉 ETL PIPELINE COMPLETE!
# ======================================================================
# 📈 FINAL RESULTS:
#    Records:            2,326,183
#    Columns:            29 - _is_zero, _streak_group, category, customer_id, date_key, ean, first_sale_timestamp, holidays, machine_eva_group, machine_key, machine_sub_group, position, prev_ean, price_mean, product_name, provider, purchase_price_kr, refiller, subcategory, was_replaced, week, week_end, week_end_first, week_share, week_start, week_start_first, weekly_sales, working_days, year
#    Total sales:        5,098,747
#    Expected sales:     5,098,918
#    Sales difference:   171 (0.00%)
#    Date range:         2018-06-25 00:00:00 to 2025-11-17 00:00:00
#    Unique machines:    1,606
#    Unique products:    1,253
#    Unique positions:   150
#    Compression:        2.3x
# ======================================================================
# INFO:planogram.moaaz_trend.train_predict:Generating features...
# 📊 Creating 7 feature group(s): BASE, TEMPORAL, PRODUCT, MACHINE, HISTORICAL_SALES, PRODUCT_LIFECYCLE, BRAND
# Feature Groups: 100%|██████████| 7/7 [03:27<00:00, 29.70s/it]
# INFO:planogram.moaaz_trend.train_predict:Training model...
# ======================================================================
# Training: RECURSIVE MULTI
# ======================================================================
# ✓ Identified 120 features
#   - Categorical: 6
#   - Numerical: 114
# ⚠ Ignored 3 columns with unsupported dtypes
# ✓ Prepared 2,150,450 samples (92.4% of input)
#
# Training 4 chained models...
#   Base input: 117 features
#   Using OOF predictions to simulate recursive features
#
#   Model 1 (week +1): 117 features
#     Train MAE: 1.406
#
#   Model 2 (week +2): 118 features (base + prev_sales)
#     Train MAE: 1.446
#
#   Model 3 (week +3): 118 features (base + prev_sales)
#     Train MAE: 1.467
#
#   Model 4 (week +4): 118 features (base + prev_sales)
# INFO:planogram.moaaz_trend.train_predict:Model saved to /Users/sam/Documents/Code/Planogram/uno/functions/planogram/moaaz_trend/artifact
#     Train MAE: 1.482
# ✓ Training complete
#
# ✓ Models saved to /Users/sam/Documents/Code/Planogram/uno/functions/planogram/moaaz_trend/artifact
# Training Complete. Model saved to /Users/sam/Documents/Code/Planogram/uno/functions/planogram/moaaz_trend/artifact

# %%
# Generate Predictions
print("Starting Prediction...")


predictions = moaaz_predict(
    sales_df=sales_data,
    machines_df=machines_df,
    product_df=products_df,
    model_path=model_path
)

print(f"Generated {len(predictions)} predictions.")
display(predictions.head())
# Out:
# Starting Prediction...
# ✓ Models loaded from /Users/sam/Documents/Code/Planogram/uno/functions/planogram/moaaz_trend/artifact
# INFO:planogram.moaaz_trend.predict:Filtering raw sales data: 2024-11-19 23:59:50+00:00 onwards
# 🚀 STARTING ETL PIPELINE
# ======================================================================
# Input: 773,231 raw transactions
# Input columns: 32 - address, card_brand, card_type, category, currency, customer_id, ean, is_ICA_refiller, latitude, local_timestamp, longitude, machine_eva_group, machine_group_tag, machine_id, machine_key, machine_model, machine_name, machine_sub_group, moms, nayax_name, position, price, product_name, provider, purchase_price_kr, pusher_friendly, refiller, sielaff_id, spiral, subcategory, too_unspecific, width
# Date range: 2024-11-20 00:02:37+00:00 to 2025-11-18 23:59:50+00:00
# Machines: 227
# Products: 817
# ======================================================================
#
# 🔧 STEP 1: DATA CLEANING
# 🧹 CLEANING SALES DATA
# ==================================================
# Starting with 773,231 transactions
# ✓ Removed 27,171 rows with missing essential fields
# ✓ Removed 37 test transactions (price ≤ 2 SEK)
# ✓ Removed 3 transactions from 1 test machines
# ✓ Removed 5,898 rows with missing provider
# ✓ Kept 14 relevant columns
# ==================================================
# ✅ CLEANING COMPLETE
#    Original: 773,231 transactions
#    Removed:  33,109 transactions (4.3%)
#    Final:    740,122 transactions
# ==================================================
# ✓ After cleaning: 740,122 transactions
# ✓ Columns: 14 - category, customer_id, ean, local_timestamp, machine_eva_group, machine_key, machine_sub_group, position, price, product_name, provider, purchase_price_kr, refiller, subcategory
# ✓ Total sales (transactions): 740,122
#
# 📊 STEP 2a: POSITION-LEVEL WEEKLY AGGREGATION
# 📊 AGGREGATING TO WEEKLY LEVEL (POSITION-LEVEL)
# ==================================================
# Starting with 740,122 transactions
# ✓ Grouping by: machine_key, position, ean, year, week
# ==================================================
# ✅ WEEKLY AGGREGATION COMPLETE
#    Original transactions: 740,122
#    Weekly records:        184,979
#    Compression ratio:     4.0x
#    Unique machines:       226
#    Unique products:       774
#    Unique positions:      61
# ==================================================
# ✓ After aggregation: 184,979 records
# ✓ Columns: 19 - category_first, customer_id_first, ean, first_sale_timestamp, machine_eva_group_first, machine_key, machine_sub_group_first, position, price_mean, product_name_first, provider_first, purchase_price_kr_first, refiller_first, subcategory_first, week, week_end_first, week_start_first, weekly_sales, year
# ✓ Total sales: 740,122 (expected: 740,122, diff: 0)
#
# 🏗️ STEP 2b: BUILDING MACHINE SNAPSHOTS
# 🏗️ BUILDING MACHINE SNAPSHOTS
# ==================================================
# 🔄 DETECTING PRODUCT SWAPS
# ==================================================
# ✓ Detected 6,395 product swaps
# ==================================================
# 📏 CALCULATING WEEK SHARES
# ==================================================
# ✓ Calculated week shares for 6,395 swapped products
# ✓ 178,584 products with full week (week_share = 1.0)
# ==================================================
# ➕ ADDING OUTGOING PRODUCT ENTRIES
# ==================================================
# ✓ Building metadata lookup for 6,395 outgoing products...
# ✓ Added 4,161 outgoing product entries
# ==================================================
# 📸 CREATING COMPLETE SNAPSHOTS (OPTIMIZED)
# ==================================================
# ✓ Generating week_start and week_end from year/week
# ✓ Input: 189,140 records
# ✓ Built grid: 357,697 potential slots
# ✓ Merged with data: 363,422 records
# ✓ Forward-filled 4 columns
# ✓ Removed empty slots: 340,381 records remain
# ✓ Removed 49,932 stale records (≥8 weeks no sales)
# ⚠️  Fixed 122 positions with >2 entries in same week
# ✓ Removed 125 duplicate entries
# ✓ Final snapshots: 290,324 records
# ✓ Expansion ratio: 1.53x
# ==================================================
# 🧹 REMOVING STALE PRODUCTS AND MACHINES
# ==================================================
# Step 1: Identifying stale products (8+ weeks zero sales)...
# ✓ Removed 34,032 stale entries from 3,654 products
# Step 2: Identifying decommissioned machines (3+ weeks total zero sales)...
# INFO:planogram.moaaz_trend.utils.calendar:Loaded 180 Swedish holidays
# ✓ Removed 0 entries from 25 machines with decommissioned periods
# ==================================================
# ✅ REMOVAL COMPLETE
#    Original records: 290,324
#    Removed:          34,032 (11.7%)
#    Final records:    256,292
# ==================================================
# ==================================================
# ✅ MACHINE SNAPSHOTS COMPLETE
# ==================================================
# ✓ After snapshot creation: 256,292 records
# ✓ Columns: 27 - _is_zero, _streak_group, category_first, customer_id_first, date_key, ean, first_sale_timestamp, machine_eva_group_first, machine_key, machine_sub_group_first, position, prev_ean, price_mean, product_name_first, provider_first, purchase_price_kr_first, refiller_first, subcategory_first, was_replaced, week, week_end, week_end_first, week_share, week_start, week_start_first, weekly_sales, year
# ✓ Total sales: 740,083 (expected: 740,122, diff: 39)
#
# 📅 STEP 3: CALENDAR INTEGRATION
# 📅 ADDING CALENDAR INFORMATION
# ==================================================
# Processing 256,292 weekly records
# ✓ Initializing Swedish holiday calendar
# ✓ Found 53 unique weeks
# ✓ Pre-calculating working days and holidays...
# ✓ Pre-calculated calendar info for 53 unique weeks
# ✓ Mapping calendar info (vectorized)...
# ==================================================
# ✅ CALENDAR INTEGRATION COMPLETE
#    Records processed: 256,292
#    Unique weeks:      53
# ==================================================
# ✓ After calendar: 29 columns (added 2)
#
# ======================================================================
# 🎉 ETL PIPELINE COMPLETE!
# ======================================================================
# 📈 FINAL RESULTS:
#    Records:            256,292
#    Columns:            29 - _is_zero, _streak_group, category, customer_id, date_key, ean, first_sale_timestamp, holidays, machine_eva_group, machine_key, machine_sub_group, position, prev_ean, price_mean, product_name, provider, purchase_price_kr, refiller, subcategory, was_replaced, week, week_end, week_end_first, week_share, week_start, week_start_first, weekly_sales, working_days, year
#    Total sales:        740,083
#    Expected sales:     740,122
#    Sales difference:   39 (0.01%)
#    Date range:         2024-11-18 00:00:00 to 2025-11-17 00:00:00
#    Unique machines:    226
#    Unique products:    774
#    Unique positions:   61
#    Compression:        3.0x
# ======================================================================
# INFO:planogram.moaaz_trend.predict:Preparing prediction data for target week: 2025-11-24 (derived from max history: 2025-11-17)
# INFO:planogram.moaaz_trend.predict:Using 234 machines from machines_df
# INFO:planogram.moaaz_trend.predict:Using 1416 products from product_df
# INFO:planogram.moaaz_trend.predict:Created 331,344 (machine, product) combinations
# INFO:planogram.moaaz_trend.predict:Created 331,344 future prediction rows for 2025-11-24
# 📊 Creating 7 feature group(s): BASE, TEMPORAL, PRODUCT, MACHINE, HISTORICAL_SALES, PRODUCT_LIFECYCLE, BRAND
# Feature Groups: 100%|██████████| 7/7 [00:38<00:00,  5.45s/it]
# INFO:planogram.moaaz_trend.predict:Generating predictions for 331344 items for week of 2025-11-24
# ======================================================================
# Generating Predictions: RECURSIVE MULTI
# ======================================================================
# ✓ Prepared 331,344 samples for prediction
# ✓ Generated 331,344 predictions
#
# Generated 331344 predictions.
#                           machine_key              ean week_start  \
# 0  1. Viadidakt Katrineholm_230547890  2200121649944.0 2025-11-24
# 1  1. Viadidakt Katrineholm_230547890  4030300022682.0 2025-11-24
# 2  1. Viadidakt Katrineholm_230547890  7350144680037.0 2025-11-24
# 3  1. Viadidakt Katrineholm_230547890  7350144680068.0 2025-11-24
# 4  1. Viadidakt Katrineholm_230547890  7350144680099.0 2025-11-24
#
#   trusted_prediction  pred_week_1  pred_week_2  pred_week_3  pred_week_4
# 0              False     5.638758     5.766668     4.349124     3.882371
# 1              False     6.255793     5.786046     3.689594     3.552881
# 2              False     4.249914     3.327425     4.167014     4.049806
# 3              False     4.249914     3.327425     4.167014     4.049806
# 4              False     6.374361     6.488276     3.883060     3.770433

# %%
predictions_names = map_ean_to_product_name(
    df=predictions,
    product_df=products_df
)

predictions_names.sort_values(by="pred_week_1", ascending=False)
# Out:
# WARNING:planogram.moaaz_trend.predict:Found 544 duplicate EANs in product_df, using first occurrence for each
#                                   machine_key              ean week_start  \
# 11393    PRO M - Bilbolaget Uppsala_874347336  5760466913133.0 2025-11-24
# 157562  Mat - Dahl Ulvsätra vänster_587343290  7350112800078.0 2025-11-24
# 133238        Mat - Gåshaga 1 Höger_260016462  7318690501718.0 2025-11-24
# 134199            Mat - IAR Systems_155510204  7318690132684.0 2025-11-24
# 133281       Mat - Gåshaga 2 Mitten_257032889  4318020172413.0 2025-11-24
# ...                                       ...              ...        ...
# 242195              Mat - SMP Ilsbo_548337221  4011800563516.0 2025-11-24
# 305915                  Conapto nya_619402560  5000159376655.0 2025-11-24
# 325739  Pro M - Billerud Skärblacka_342051139  7317731501205.0 2025-11-24
# 29795     Pro M - Ahlsells Karlstad_256226127  7310401003290.0 2025-11-24
# 240779       Coca Cola Jordbro 2 Ny_119125826  7310100971708.0 2025-11-24
#
#        trusted_prediction  pred_week_1  pred_week_2  pred_week_3  pred_week_4  \
# 11393               False    10.988876     8.779390     8.995770     3.695104
# 157562              False     9.997738    12.272857    14.238729    15.666771
# 133238              False     9.719573    11.326602    10.632500     9.538171
# 134199              False     9.579480     9.733576     7.539760     7.785613
# 133281              False     9.268907    12.461085    16.371387    14.667116
# ...                   ...          ...          ...          ...          ...
# 242195               True     0.346284     1.698241     2.581617     3.820620
# 305915              False     0.152919     2.033530     3.852900     3.400677
# 325739              False     0.152919     2.033530     3.843585     3.400677
# 29795               False     0.152919     2.031733     3.843585     3.445266
# 240779              False     0.152919     2.031733     3.843585     3.833550
#
#                            product_name
# 11393         Kelda Toscansk Tomatsoppa
# 157562  IQ Fuel Hydrate Lemon Yuzu 33cl
# 133238        ICA Caesarsallad Kyckling
# 134199           ICA Röd Curry Kyckling
# 133281             ICA Mandlar Eco 100g
# ...                                 ...
# 242195              Corny Big Chocolate
# 305915                     Skittles 38g
# 325739               Saltå Kvarn Russin
# 29795       Schweppes Indian Tonic 50cl
# 240779                   Semper Lasagne
#
# [331344 rows x 9 columns]

# %%
from inventory_score import calculate_inventory_scores

inventory_scores = calculate_inventory_scores(
    machines_df=machines_df,
    products_df=products_df,
    predictions_df=predictions
)

# %%
inventory_scores
# Out:
#                                         machine_key  inventory_score
# 0                            PRO M - Wämö_594015928         0.600440
# 1    Pro - Länsstyrelsen Västerås Vänster_639546040         0.549767
# 2               PRO S - Verisure Linköping_72327866         0.697071
# 3                        Mat - Vasakronan_219574714         0.594431
# 4                 912. Postnord Mat liten_521675443         0.676619
# ..                                              ...              ...
# 225                   Pro Custom - SCA Ny_204330420         0.780353
# 226              Mat - Nordlock Mattmar 2_585332045         0.593319
# 227              Mat - Hangon Hillerstorp_877492288         0.672930
# 228     PRO M 8 - Försvarsmakten Enköping_580593846         0.667466
# 229       Pro M - Kunskapsskolan Enköping_248096330         0.660481
#
# [230 rows x 2 columns]

# %%
machines_df
# Out:
#                                                  slots machine_sub_group  \
# 0    [{'is_discount': False, 'price': 75, 'stock_cu...           Sjukhus
# 1    [{'is_discount': False, 'image_url': 'https://...            Kontor
# 2    [{'is_discount': False, 'category': 'Mat', 'st...            Kontor
# 3    [{'product_name': 'Gooh! Korv Stroganoff', 'ca...            Kontor
# 4    [{'product_name': 'Gooh! Korv Stroganoff', 'ca...          Industri
# ..                                                 ...               ...
# 229  [{'is_discount': False, 'category': None, 'sto...          Industri
# 230  [{'is_discount': False, 'category': 'Mat', 'st...          Industri
# 231  [{'is_discount': False, 'category': 'Övrigt', ...          Industri
# 232  [{'is_discount': False, 'category': 'Mat', 'st...           Militär
# 233  [{'is_discount': False, 'category': 'Mat', 'st...        Grundskola
#
#     sielaff_id machine_eva_group  n_sales  \
# 0     90548319      WAITING ROOM     1750
# 1          nan              WORK      802
# 2     90543705              WORK    11070
# 3            0              WORK     8447
# 4     90548296              WORK     3226
# ..         ...               ...      ...
# 229   90543340              WORK     5417
# 230   90539188              WORK    13626
# 231   90504601              WORK    24683
# 232   90552814              WORK     4680
# 233        nan     SCHOOLS, UNIV     3895
#
#                                                  notes  \
# 0    [{'text': 'Använd detta fält för att notera pr...
# 1    [{'text': 'Använd detta fält för att notera pr...
# 2    [{'text': 'Använd detta fält för att notera pr...
# 3    [{'text': 'Använd detta fält för att notera pr...
# 4    [{'text': 'Använd detta fält för att notera pr...
# ..                                                 ...
# 229  [{'text': 'Använd detta fält för att notera pr...
# 230  [{'text': 'Använd detta fält för att notera pr...
# 231  [{'text': 'Använd detta fält för att notera pr...
# 232  [{'text': 'Använd detta fält för att notera pr...
# 233  [{'text': 'Använd detta fält för att notera pr...
#
#                              machine_name  \
# 0                            PRO M - Wämö
# 1    Pro - Länsstyrelsen Västerås Vänster
# 2              PRO S - Verisure Linköping
# 3                        Mat - Vasakronan
# 4                 912. Postnord Mat liten
# ..                                    ...
# 229                   Pro Custom - SCA Ny
# 230              Mat - Nordlock Mattmar 2
# 231              Mat - Hangon Hillerstorp
# 232     PRO M 8 - Försvarsmakten Enköping
# 233       Pro M - Kunskapsskolan Enköping
#
#                               product_wishes   last_sale machine_id  \
# 0                                         []  2025-02-16  594015928
# 1    [My new product wish, Test, Test, Test]  2025-02-14  639546040
# 2                                        NaN  2025-02-16   72327866
# 3                                         []  2025-02-16  219574714
# 4                                        NaN  2025-02-14  521675443
# ..                                       ...         ...        ...
# 229                                      NaN  2025-02-16  204330420
# 230                                      NaN  2025-02-16  585332045
# 231                                      NaN  2025-02-15  877492288
# 232                                      NaN  2025-02-14  580593846
# 233                                      NaN  2025-02-14  248096330
#
#     machine_group_tag machine_model  \
# 0                 NaN         PRO M
# 1                 NaN         PRO M
# 2                 NaN         PRO S
# 3                 NaN         PRO M
# 4                 NaN         PRO M
# ..                ...           ...
# 229               NaN         PRO M
# 230               NaN         PRO M
# 231               NaN         PRO M
# 232               NaN         PRO M
# 233               NaN         PRO M
#
#                                         machine_key  \
# 0                            PRO M - Wämö_594015928
# 1    Pro - Länsstyrelsen Västerås Vänster_639546040
# 2               PRO S - Verisure Linköping_72327866
# 3                        Mat - Vasakronan_219574714
# 4                 912. Postnord Mat liten_521675443
# ..                                              ...
# 229                   Pro Custom - SCA Ny_204330420
# 230              Mat - Nordlock Mattmar 2_585332045
# 231              Mat - Hangon Hillerstorp_877492288
# 232     PRO M 8 - Försvarsmakten Enköping_580593846
# 233       Pro M - Kunskapsskolan Enköping_248096330
#
#                                              refillers  \
# 0                                    [Region Blekinge]
# 1                                      [Ozer Foods AB]
# 2                              [Tornby Minimarknad AB]
# 3                                    [ICA Nära Stabby]
# 4                            [Magnus Jeppsson Livs AB]
# ..                                                 ...
# 229                        [Kvantum Nacksta Fasand AB]
# 230                    [E Bernhardssons Matmarknad AB]
# 231  [ICA Nära HillerstorpJJ Anner Mat AB, Ekbacken...
# 232                                      [Wems Mat AB]
# 233                                      [Wems Mat AB]
#
#                                               location  sales_counter  \
# 0    {'address': 'Bättringsvägen 2, Byggnad 4, 371 ...            0.0
# 1    {'address': 'Västra Ringvägen 1, 721 86 Väster...            0.0
# 2    {'address': 'Gumpekullavägen 8, 582 78 Linköpi...            0.0
# 3    {'address': 'Ljusbärargatan 2, 754 23 Uppsala,...            0.0
# 4    {'address': 'Industrigatan 5, 641 34 Katrineho...            0.0
# ..                                                 ...            ...
# 229  {'address': 'Tegelvägen 3a, 853 50 Sundsvall, ...            0.0
# 230  {'address': 'Halabacken 180, 837 91 Mattmar, S...            0.0
# 231  {'address': 'Industrivägen 7, 335 73 Hillersto...            0.0
# 232  {'address': 'Garnisonsvägen, 749 40 Enköping, ...            0.0
# 233  {'address': 'Friggavägen 1, 745 69 Enköping, S...            0.0
#
#                    doc_id lastUpdated createdAt                    id
# 0    0I7EsuVLPWhooW6JFch9         NaN       NaN  0I7EsuVLPWhooW6JFch9
# 1    0UFPqnnadAqS8Xz7HPzH         NaN       NaN  0UFPqnnadAqS8Xz7HPzH
# 2    1Ek0S7N3BoYqhL0lCRFq         NaN       NaN  1Ek0S7N3BoYqhL0lCRFq
# 3    1MPyIWSuen3Znb6KpapR         NaN       NaN  1MPyIWSuen3Znb6KpapR
# 4    1VV42yepdPw5peDOIFC2  2025-11-11       NaN  1VV42yepdPw5peDOIFC2
# ..                    ...         ...       ...                   ...
# 229  yvU8JwBkt8Rkwp2MQO4e         NaN       NaN  yvU8JwBkt8Rkwp2MQO4e
# 230  z9HDtuXr00P9uR1kqewJ         NaN       NaN  z9HDtuXr00P9uR1kqewJ
# 231  zUMpU2iEVJiOblHGZKu5         NaN       NaN  zUMpU2iEVJiOblHGZKu5
# 232  zUrR4cRLQ76A0eEC1dTV         NaN       NaN  zUrR4cRLQ76A0eEC1dTV
# 233  zsUL7Njfk8Pk1fPSftNf         NaN       NaN  zsUL7Njfk8Pk1fPSftNf
#
# [234 rows x 20 columns]
